# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasan-ES/ML/blob/main/Vector_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
plt.quiver?

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# (-8.0, 8.0)

# %%
array = np.asarray([0,0,1,2])
array_1 = np.asarray([0,0,3,4])
sum = array+array_1
print(sum)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.quiver(0,0,4,6,scale_units='xy',angles='xy',scale=1)
plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# (-8.0, 8.0)

# %%
array = np.asarray([0,0,1,2])
array_1 = np.asarray([0,0,3,4])
sub = array-array_1
print(sub)
# Out:
# [ 0  0 -2 -2]

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.quiver(0,0,-2,-2,scale_units='xy',angles='xy',scale=1)
plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# (-8.0, 8.0)

# %%
array = np.asarray([0,0,1,2])
product = 2*array_1
print(product)
# Out:
# [0 0 6 8]

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.quiver(0,0,6,8,scale_units='xy',angles='xy',scale=1)
plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# (-8.0, 8.0)
